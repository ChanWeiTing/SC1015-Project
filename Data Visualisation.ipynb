# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %% [markdown]
# # Visualisation of Cleaned Data
# can reference this link for advance visualisation based on year
# https://www.kaggle.com/code/andreshg/video-games-eda-and-visualization#Load-data-%F0%9F%93%9A

# %%
df = pd.read_csv('Cleaned Data.csv',index_col= 0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7013 entries, 0 to 16709
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             7013 non-null   object
#  1   Platform         7013 non-null   object
#  2   Year_of_Release  6890 non-null   float64
#  3   Genre            7013 non-null   object
#  4   Publisher        7009 non-null   object
#  5   NA_Sales         7013 non-null   float64
#  6   EU_Sales         7013 non-null   float64
#  7   JP_Sales         7013 non-null   float64
#  8   Other_Sales      7013 non-null   float64
#  9   Global_Sales     7013 non-null   float64
#  10  Critic_Score     7013 non-null   float64
#  11  Critic_Count     7013 non-null   float64
#  12  User_Score       7013 non-null   float64
#  13  User_Count       7013 non-null   float64
#  14  Developer        7013 non-null   object
#  15  Rating           6947 non-null   object
# dtypes: float64(10), object(6)
# memory usage: 931.4+ KB

# %% [markdown]
# ## Categorical Data
#
# Categorical Data(5): Platform, Genre, Publisher, Developer, Rating
#
# To work on: year

# %%
catdf = df[["Platform","Genre","Publisher","Developer","Rating"]]
catdf
# Out:
#       Platform      Genre                     Publisher           Developer  \
# 0          Wii     Sports                      Nintendo            Nintendo
# 2          Wii     Racing                      Nintendo            Nintendo
# 3          Wii     Sports                      Nintendo            Nintendo
# 6           DS   Platform                      Nintendo            Nintendo
# 7          Wii       Misc                      Nintendo            Nintendo
# ...        ...        ...                           ...                 ...
# 16677      GBA   Fighting                  Midway Games     Criterion Games
# 16696       PC     Action  Konami Digital Entertainment  Kojima Productions
# 16700       PC    Shooter                     Destineer        Atomic Games
# 16706       PC   Strategy                       Unknown              SimBin
# 16709       PC  Adventure             DTP Entertainment   DTP Entertainment
#
#       Rating
# 0          E
# 2          E
# 3          E
# 6          E
# 7          E
# ...      ...
# 16677      M
# 16696      M
# 16700      T
# 16706   E10+
# 16709    NaN
#
# [7013 rows x 5 columns]

# %%
catdf["Platform"].value_counts()
# Out:
# PS2     1161
# X360     880
# PS3      789
# PC       702
# XB       580
# Wii      492
# DS       469
# PSP      393
# GC       356
# PS4      249
# GBA      241
# XOne     165
# 3DS      158
# PS       156
# PSV      119
# WiiU      89
# DC        14
# Name: Platform, dtype: int64

# %%
sb.catplot(y = "Platform", data = catdf, kind = "count")
plt.show()

# %%
catdf["Genre"].value_counts()

# %%
sb.catplot(y = "Genre", data = catdf, kind = "count")
plt.show()

# %%
cPublisher=df['Publisher'].value_counts()
print(cPublisher)
# Out:
# Electronic Arts                956
# Ubisoft                        500
# Activision                     498
# Sony Computer Entertainment    316
# THQ                            309
#                               ...
# NDA Productions                  1
# Moss                             1
# Crytek                           1
# Funsta                           1
# NewKidCo                         1
# Name: Publisher, Length: 271, dtype: int64

# %%
cPublisher = cPublisher[cPublisher >= 30]
print(cPublisher)
# Out:
# Electronic Arts                           956
# Ubisoft                                   500
# Activision                                498
# Sony Computer Entertainment               316
# THQ                                       309
# Nintendo                                  294
# Sega                                      291
# Take-Two Interactive                      274
# Konami Digital Entertainment              250
# Namco Bandai Games                        246
# Capcom                                    200
# Atari                                     179
# Microsoft Game Studios                    141
# Tecmo Koei                                140
# Warner Bros. Interactive Entertainment    139
# Square Enix                               135
# Eidos Interactive                         125
# Vivendi Games                             116
# Codemasters                               114
# Midway Games                              105
# 505 Games                                  80
# Deep Silver                                79
# Disney Interactive Studios                 75
# LucasArts                                  71
# Unknown                                    69
# Acclaim Entertainment                      66
# Nippon Ichi Software                       61
# Rising Star Games                          53
# Bethesda Softworks                         50
# D3Publisher                                36
# Focus Home Interactive                     35
# Ignition Entertainment                     30
# Name: Publisher, dtype: int64

# %%
cPublisher.plot(kind='barh')
plt.show()

# %%
cDeveloper=df['Developer'].value_counts()
print(cDeveloper)
# Out:
# EA Canada                                 152
# EA Sports                                 145
# Capcom                                    128
# Ubisoft                                   104
# Konami                                    100
#                                          ...
# Netherock Ltd.                              1
# Interchannel                                1
# Warner Bros. Interactive Entertainment      1
# Crawfish Interactive                        1
# DTP Entertainment                           1
# Name: Developer, Length: 1312, dtype: int64

# %%
cDeveloper = cDeveloper[cDeveloper >= 30]
print(cDeveloper)
# Out:
# EA Canada                         152
# EA Sports                         145
# Capcom                            128
# Ubisoft                           104
# Konami                            100
# Ubisoft Montreal                   88
# EA Tiburon                         86
# Omega Force                        69
# Traveller's Tales                  68
# Electronic Arts                    68
# Visual Concepts                    68
# Nintendo                           68
# Codemasters                        59
# Vicarious Visions                  59
# Namco                              56
# Yuke's                             48
# Midway                             44
# Neversoft Entertainment            43
# TT Games                           43
# Treyarch                           42
# Maxis                              42
# From Software                      42
# Eurocom Entertainment Software     40
# Square Enix                        40
# Sonic Team                         36
# TOSE                               34
# Radical Entertainment              34
# Rebellion                          32
# Arc System Works                   32
# Sega                               32
# Harmonix Music Systems             32
# Artificial Mind and Movement       32
# High Voltage Software              31
# Name: Developer, dtype: int64

# %%
cDeveloper.plot(kind='barh')
plt.show()

# %%
catdf["Rating"].value_counts()
# Out:
# T       2420
# E       2118
# M       1459
# E10+     946
# RP         2
# AO         1
# K-A        1
# Name: Rating, dtype: int64

# %%
sb.catplot(y = "Rating", data = catdf, kind = "count")
plt.show()

# %% [markdown]
# ## Numerical Data
#
# Numerical Data(9): NA sales, EU sales, JP sales, Other sales, Global sales, Critic score, Critic count, User score, User count

# %%
numdf = df[["NA_Sales","EU_Sales","JP_Sales","Other_Sales","Global_Sales","Critic_Score","Critic_Count","User_Score","User_Count"]]
numdf
# Out:
#        NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0         41.36     28.96      3.77         8.45         82.53          76.0
# 2         15.68     12.76      3.79         3.29         35.52          82.0
# 3         15.61     10.93      3.28         2.95         32.77          80.0
# 6         11.28      9.14      6.50         2.88         29.80          89.0
# 7         13.96      9.18      2.93         2.84         28.92          58.0
# ...         ...       ...       ...          ...           ...           ...
# 16677      0.01      0.00      0.00         0.00          0.01          81.0
# 16696      0.00      0.01      0.00         0.00          0.01          80.0
# 16700      0.01      0.00      0.00         0.00          0.01          61.0
# 16706      0.00      0.01      0.00         0.00          0.01          60.0
# 16709      0.00      0.01      0.00         0.00          0.01          63.0
#
#        Critic_Count  User_Score  User_Count
# 0              51.0         8.0       322.0
# 2              73.0         8.3       709.0
# 3              73.0         8.0       192.0
# 6              65.0         8.5       431.0
# 7              41.0         6.6       129.0
# ...             ...         ...         ...
# 16677          12.0         8.8         9.0
# 16696          20.0         7.6       412.0
# 16700          12.0         5.8        43.0
# 16706          12.0         7.2        13.0
# 16709           6.0         5.8         8.0
#
# [7013 rows x 9 columns]

# %%
numdf.describe()
# Out:
#           NA_Sales     EU_Sales     JP_Sales  Other_Sales  Global_Sales  \
# count  7013.000000  7013.000000  7013.000000  7013.000000   7013.000000
# mean      0.389457     0.233208     0.062987     0.081566      0.767403
# std       0.957297     0.679387     0.284239     0.266664      1.940812
# min       0.000000     0.000000     0.000000     0.000000      0.010000
# 25%       0.060000     0.020000     0.000000     0.010000      0.110000
# 50%       0.150000     0.060000     0.000000     0.020000      0.290000
# 75%       0.390000     0.210000     0.010000     0.070000      0.750000
# max      41.360000    28.960000     6.500000    10.570000     82.530000
#
#        Critic_Score  Critic_Count   User_Score    User_Count
# count   7013.000000   7013.000000  7013.000000   7013.000000
# mean      70.256238     28.792813     7.183017    173.507771
# std       13.877061     19.167447     1.441015    582.134472
# min       13.000000      3.000000     0.500000      4.000000
# 25%       62.000000     14.000000     6.500000     11.000000
# 50%       72.000000     24.000000     7.500000     27.000000
# 75%       80.000000     39.000000     8.200000     89.000000
# max       98.000000    113.000000     9.600000  10665.000000

# %% [markdown]
# ### Sales
#
# Possbile ideas: Plot sales according to total sales of platform/publisher

# %%
# f, axes = plt.subplots(5,1,figsize=(40,60))
f = plt.figure(figsize=(16, 8))
sb.boxplot(data = numdf['NA_Sales'], orient = "h")
plt.show()

# %%
# f, axes = plt.subplots(5,1,figsize=(40,60))
f = plt.figure(figsize=(16, 8))
sb.boxplot(data = numdf['Global_Sales'], orient = "h")
plt.show()

# %%
# f, axes = plt.subplots(5,1,figsize=(40,60))
f = plt.figure(figsize=(16, 8))
sb.histplot(data = numdf['Global_Sales'])
plt.show()

# %%
# f, axes = plt.subplots(5,1,figsize=(40,60))
f = plt.figure(figsize=(16, 8))
sb.violinplot(data = numdf['Global_Sales'], orient = "h")
plt.show()

# %%
cGlobals=numdf['Global_Sales'].value_counts()
print(cGlobals)
# Out:
# 0.02     222
# 0.05     182
# 0.03     179
# 0.04     170
# 0.06     168
#         ...
# 4.45       1
# 4.46       1
# 4.49       1
# 4.57       1
# 82.53      1
# Name: Global_Sales, Length: 538, dtype: int64

# %% [markdown]
# ### Score
# Time to analyse and find our important variable, probably User Score or Critic Score

# %%
numdf["User_Score"].describe()
# Out:
# count    7013.000000
# mean        7.183017
# std         1.441015
# min         0.500000
# 25%         6.500000
# 50%         7.500000
# 75%         8.200000
# max         9.600000
# Name: User_Score, dtype: float64

# %%
f, axes = plt.subplots(3,figsize=(24, 24))
sb.boxplot(data = numdf["User_Score"], orient = "h", ax = axes[0])
sb.histplot(data = numdf["User_Score"],ax = axes[1])
sb.violinplot(data = numdf["User_Score"], orient = "h", ax = axes[2])
plt.show()

# %%
numdf["User_Count"].describe()
# Out:
# count     7013.000000
# mean       173.507771
# std        582.134472
# min          4.000000
# 25%         11.000000
# 50%         27.000000
# 75%         89.000000
# max      10665.000000
# Name: User_Count, dtype: float64

# %%
f, axes = plt.subplots(3,figsize=(24, 24))
sb.boxplot(data = numdf["User_Count"], orient = "h", ax = axes[0])
sb.histplot(data = numdf["User_Count"],ax = axes[1])
sb.violinplot(data = numdf["User_Count"], orient = "h", ax = axes[2])
plt.show()

# %% [markdown]
# Count kind bad and score better

# %%
numdf["Critic_Score"].describe()
# Out:
# count    7013.000000
# mean       70.256238
# std        13.877061
# min        13.000000
# 25%        62.000000
# 50%        72.000000
# 75%        80.000000
# max        98.000000
# Name: Critic_Score, dtype: float64

# %%
f, axes = plt.subplots(3,figsize=(24, 24))
sb.boxplot(data = numdf["Critic_Score"], orient = "h", ax = axes[0])
sb.histplot(data = numdf["Critic_Score"],ax = axes[1])
sb.violinplot(data = numdf["Critic_Score"], orient = "h", ax = axes[2])
plt.show()

# %%
# Heatmap of the Correlation Matrix
f = plt.figure(figsize=(12,12))
sb.heatmap(numdf.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f")
plt.show()

# %%
sb.pairplot(data = numdf, corner = True)
plt.show()
