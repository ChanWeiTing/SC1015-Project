# %%
import pandas as pd

# %%
df = pd.read_csv('cleaned_derived_data2.csv')
df
# Out:
#       Unnamed: 0                               Name Platform  Year_of_Release  \
# 0              0                         Wii Sports      Wii           2006.0
# 1              2                     Mario Kart Wii      Wii           2008.0
# 2              3                  Wii Sports Resort      Wii           2009.0
# 3              6              New Super Mario Bros.       DS           2006.0
# 4              7                           Wii Play      Wii           2006.0
# ...          ...                                ...      ...              ...
# 6885       16677     Mortal Kombat: Deadly Alliance      GBA           2002.0
# 6886       16696  Metal Gear Solid V: Ground Zeroes       PC           2014.0
# 6887       16700                             Breach       PC           2011.0
# 6888       16706            STORM: Frontline Nation       PC           2011.0
# 6889       16709                            15 Days       PC           2009.0
#
#           Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 0        Sports                      Nintendo     41.36     28.96      3.77
# 1        Racing                      Nintendo     15.68     12.76      3.79
# 2        Sports                      Nintendo     15.61     10.93      3.28
# 3      Platform                      Nintendo     11.28      9.14      6.50
# 4          Misc                      Nintendo     13.96      9.18      2.93
# ...         ...                           ...       ...       ...       ...
# 6885   Fighting                  Midway Games      0.01      0.00      0.00
# 6886     Action  Konami Digital Entertainment      0.00      0.01      0.00
# 6887    Shooter                     Destineer      0.01      0.00      0.00
# 6888   Strategy                       Unknown      0.00      0.01      0.00
# 6889  Adventure             DTP Entertainment      0.00      0.01      0.00
#
#       Other_Sales  ...  Critic_Score  Critic_Count  User_Score  User_Count  \
# 0            8.45  ...          76.0          51.0         8.0       322.0
# 1            3.29  ...          82.0          73.0         8.3       709.0
# 2            2.95  ...          80.0          73.0         8.0       192.0
# 3            2.88  ...          89.0          65.0         8.5       431.0
# 4            2.84  ...          58.0          41.0         6.6       129.0
# ...           ...  ...           ...           ...         ...         ...
# 6885         0.00  ...          81.0          12.0         8.8         9.0
# 6886         0.00  ...          80.0          20.0         7.6       412.0
# 6887         0.00  ...          61.0          12.0         5.8        43.0
# 6888         0.00  ...          60.0          12.0         7.2        13.0
# 6889         0.00  ...          63.0           6.0         5.8         8.0
#
#                Developer Rating New_User_Score  years_since_release  \
# 0               Nintendo      E              1                 10.0
# 1               Nintendo      E              1                  8.0
# 2               Nintendo      E              1                  7.0
# 3               Nintendo      E              1                 10.0
# 4               Nintendo      E              0                 10.0
# ...                  ...    ...            ...                  ...
# 6885     Criterion Games      M              1                 14.0
# 6886  Kojima Productions      M              1                  2.0
# 6887        Atomic Games      T              0                  5.0
# 6888              SimBin   E10+              0                  5.0
# 6889   DTP Entertainment    NaN              0                  7.0
#
#       Developer_clas  Derived_global_sales
# 0                  1                     1
# 1                  1                     1
# 2                  1                     1
# 3                  1                     1
# 4                  1                     1
# ...              ...                   ...
# 6885               0                     0
# 6886               0                     0
# 6887               0                     0
# 6888               0                     0
# 6889               0                     0
#
# [6890 rows x 21 columns]

# %%
dataset = df.values

# %%
dataset
# Out:
# array([[0, 'Wii Sports', 'Wii', ..., 10.0, 1, 1],
#        [2, 'Mario Kart Wii', 'Wii', ..., 8.0, 1, 1],
#        [3, 'Wii Sports Resort', 'Wii', ..., 7.0, 1, 1],
#        ...,
#        [16700, 'Breach', 'PC', ..., 5.0, 0, 0],
#        [16706, 'STORM: Frontline Nation', 'PC', ..., 5.0, 0, 0],
#        [16709, '15 Days', 'PC', ..., 7.0, 0, 0]], dtype=object)

# %%
X = dataset[:,17:21]
Y = dataset[:,16]

# %%
from sklearn import preprocessing

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)

# %%
X_scale
# Out:
# array([[1.        , 0.32258065, 1.        , 1.        ],
#        [1.        , 0.25806452, 1.        , 1.        ],
#        [1.        , 0.22580645, 1.        , 1.        ],
#        ...,
#        [0.        , 0.16129032, 0.        , 0.        ],
#        [0.        , 0.16129032, 0.        , 0.        ],
#        [0.        , 0.22580645, 0.        , 0.        ]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_val_and_test, Y_train, Y_val_and_test = train_test_split(X_scale, Y, test_size=0.2)
X_val, X_test, Y_val, Y_test = train_test_split(X_val_and_test, Y_val_and_test, test_size=0.5)

# %%
print(X_train.shape, X_val.shape, X_test.shape, Y_train.shape, Y_val.shape, Y_test.shape)
# Out:
# (5512, 4) (689, 4) (689, 4) (5512,) (689,) (689,)

# %%
from keras.models import Sequential
from keras.layers import Dense
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28560\807270410.py in <module>
# ----> 1 from keras.models import Sequential
#       2 from keras.layers import Dense
#
# ModuleNotFoundError: No module named 'keras'
