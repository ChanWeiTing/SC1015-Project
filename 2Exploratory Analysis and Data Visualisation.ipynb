# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %% [markdown]
# # Visualisation of Cleaned Data
# can reference this link for advance visualisation based on year
# https://www.kaggle.com/code/andreshg/video-games-eda-and-visualization#Load-data-%F0%9F%93%9A

# %% [markdown]
# ### Content Page
# Univariate
# Bivariate

# %%
df = pd.read_csv('Cleaned Data.csv',index_col= 0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6890 entries, 0 to 16709
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             6890 non-null   object
#  1   Platform         6890 non-null   object
#  2   Year_of_Release  6890 non-null   float64
#  3   Genre            6890 non-null   object
#  4   Publisher        6889 non-null   object
#  5   NA_Sales         6890 non-null   float64
#  6   EU_Sales         6890 non-null   float64
#  7   JP_Sales         6890 non-null   float64
#  8   Other_Sales      6890 non-null   float64
#  9   Global_Sales     6890 non-null   float64
#  10  Critic_Score     6890 non-null   float64
#  11  Critic_Count     6890 non-null   float64
#  12  User_Score       6890 non-null   float64
#  13  User_Count       6890 non-null   float64
#  14  Developer        6890 non-null   object
#  15  Rating           6826 non-null   object
# dtypes: float64(10), object(6)
# memory usage: 915.1+ KB

# %% [markdown]
# # Univariate Visualisation

# %% [markdown]
# ## Categorical Data
#
# Categorical Data(5): Platform, Genre, Publisher, Developer, Rating
#
# To work on: year

# %%
catdf = df[["Platform","Genre","Publisher","Developer","Rating","Name"]]
catdf
# Out:
#       Platform      Genre                     Publisher           Developer  \
# 0          Wii     Sports                      Nintendo            Nintendo
# 2          Wii     Racing                      Nintendo            Nintendo
# 3          Wii     Sports                      Nintendo            Nintendo
# 6           DS   Platform                      Nintendo            Nintendo
# 7          Wii       Misc                      Nintendo            Nintendo
# ...        ...        ...                           ...                 ...
# 16677      GBA   Fighting                  Midway Games     Criterion Games
# 16696       PC     Action  Konami Digital Entertainment  Kojima Productions
# 16700       PC    Shooter                     Destineer        Atomic Games
# 16706       PC   Strategy                       Unknown              SimBin
# 16709       PC  Adventure             DTP Entertainment   DTP Entertainment
#
#       Rating                               Name
# 0          E                         Wii Sports
# 2          E                     Mario Kart Wii
# 3          E                  Wii Sports Resort
# 6          E              New Super Mario Bros.
# 7          E                           Wii Play
# ...      ...                                ...
# 16677      M     Mortal Kombat: Deadly Alliance
# 16696      M  Metal Gear Solid V: Ground Zeroes
# 16700      T                             Breach
# 16706   E10+            STORM: Frontline Nation
# 16709    NaN                            15 Days
#
# [6890 rows x 6 columns]

# %%
catdf["Platform"].value_counts()
# Out:
# PS2     1140
# X360     860
# PS3      774
# PC       687
# XB       565
# Wii      480
# DS       465
# PSP      390
# GC       348
# PS4      249
# GBA      237
# XOne     165
# 3DS      156
# PS       153
# PSV      118
# WiiU      89
# DC        14
# Name: Platform, dtype: int64

# %%
sb.catplot(y = "Platform", data = catdf, kind = "count")
plt.show()

# %%
catdf["Genre"].value_counts()
# Out:
# Action          1643
# Sports           949
# Shooter          868
# Role-Playing     715
# Racing           586
# Platform         403
# Misc             386
# Fighting         379
# Simulation       302
# Strategy         278
# Adventure        263
# Puzzle           118
# Name: Genre, dtype: int64

# %%
sb.catplot(y = "Genre", data = catdf, kind = "count")
plt.show()

# %%
cPublisher=df['Publisher'].value_counts()
print(cPublisher)
# Out:
# Electronic Arts                944
# Ubisoft                        498
# Activision                     492
# Sony Computer Entertainment    316
# THQ                            307
#                               ...
# NDA Productions                  1
# Moss                             1
# Crytek                           1
# Funsta                           1
# NewKidCo                         1
# Name: Publisher, Length: 270, dtype: int64

# %%
cPublisher = cPublisher[cPublisher >= 30]
print(cPublisher)
# Out:
# Electronic Arts                           944
# Ubisoft                                   498
# Activision                                492
# Sony Computer Entertainment               316
# THQ                                       307
# Nintendo                                  293
# Sega                                      287
# Take-Two Interactive                      273
# Konami Digital Entertainment              246
# Namco Bandai Games                        244
# Capcom                                    197
# Atari                                     176
# Microsoft Game Studios                    141
# Tecmo Koei                                140
# Square Enix                               134
# Warner Bros. Interactive Entertainment    130
# Eidos Interactive                         123
# Vivendi Games                             113
# Codemasters                               112
# Midway Games                              103
# 505 Games                                  80
# Deep Silver                                78
# Disney Interactive Studios                 74
# LucasArts                                  70
# Acclaim Entertainment                      66
# Nippon Ichi Software                       60
# Rising Star Games                          53
# Bethesda Softworks                         48
# D3Publisher                                35
# Focus Home Interactive                     34
# Ignition Entertainment                     30
# Name: Publisher, dtype: int64

# %%
cPublisher.plot(kind='barh')
plt.show()

# %%
cDeveloper=df['Developer'].value_counts()
print(cDeveloper)
# Out:
# EA Canada                                          149
# EA Sports                                          142
# Capcom                                             126
# Ubisoft                                            103
# Konami                                              97
#                                                   ...
# Magic Rings                                          1
# Artificial Mind and Movement, EA Redwood Shores      1
# BottleRocket Entertainment                           1
# Skip Ltd.                                            1
# DTP Entertainment                                    1
# Name: Developer, Length: 1304, dtype: int64

# %%
cDeveloper = cDeveloper[cDeveloper >= 30]
print(cDeveloper)
# Out:
# EA Canada                         149
# EA Sports                         142
# Capcom                            126
# Ubisoft                           103
# Konami                             97
# Ubisoft Montreal                   87
# EA Tiburon                         82
# Omega Force                        69
# Nintendo                           68
# Visual Concepts                    68
# Electronic Arts                    67
# Traveller's Tales                  59
# Codemasters                        58
# Vicarious Visions                  57
# Namco                              56
# Yuke's                             48
# TT Games                           43
# Maxis                              42
# Neversoft Entertainment            42
# Midway                             42
# From Software                      42
# Treyarch                           41
# Eurocom Entertainment Software     40
# Square Enix                        39
# Sonic Team                         35
# TOSE                               34
# Radical Entertainment              33
# Sega                               32
# Rebellion                          32
# Arc System Works                   32
# High Voltage Software              30
# Name: Developer, dtype: int64

# %%
cDeveloper.plot(kind='barh')
plt.show()

# %%
catdf["Rating"].value_counts()
# Out:
# T       2378
# E       2082
# M       1433
# E10+     930
# AO         1
# K-A        1
# RP         1
# Name: Rating, dtype: int64

# %%
sb.catplot(y = "Rating", data = catdf, kind = "count")
plt.show()

# %%
catdf["Name"].value_counts()
# Out:
# LEGO Star Wars II: The Original Trilogy                  8
# Need for Speed: Most Wanted                              8
# Madden NFL 07                                            8
# Tomb Raider: Legend                                      7
# Need for Speed Carbon                                    7
#                                                         ..
# Donkey Konga 2                                           1
# Combat of Giants: Dinosaurs 3D                           1
# Final Fantasy Crystal Chronicles: The Crystal Bearers    1
# Until Dawn: Rush of Blood                                1
# 15 Days                                                  1
# Name: Name, Length: 4427, dtype: int64

# %%
sb.catplot(y = "Name", data = catdf, kind = "count")
plt.show()
# Out:
# C:\Users\jason\anaconda3\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)

# %%
catdf["Name"].describe()
# Out:
# count                                        6890
# unique                                       4427
# top       LEGO Star Wars II: The Original Trilogy
# freq                                            8
# Name: Name, dtype: object

# %% [markdown]
# After checking the raw data, we are able to find out that there are multiple games under the same name but released under different platforms

# %% [markdown]
# ## Numerical Data
#
# Numerical Data(10): NA sales, EU sales, JP sales, Other sales, Global sales, Critic score, Critic count, User score, User count, Year of Release

# %%
numdf = df[["NA_Sales","EU_Sales","JP_Sales","Other_Sales","Global_Sales","Critic_Score","Critic_Count","User_Score","User_Count","Year_of_Release"]]
numdf
# Out:
#        NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0         41.36     28.96      3.77         8.45         82.53          76.0
# 2         15.68     12.76      3.79         3.29         35.52          82.0
# 3         15.61     10.93      3.28         2.95         32.77          80.0
# 6         11.28      9.14      6.50         2.88         29.80          89.0
# 7         13.96      9.18      2.93         2.84         28.92          58.0
# ...         ...       ...       ...          ...           ...           ...
# 16677      0.01      0.00      0.00         0.00          0.01          81.0
# 16696      0.00      0.01      0.00         0.00          0.01          80.0
# 16700      0.01      0.00      0.00         0.00          0.01          61.0
# 16706      0.00      0.01      0.00         0.00          0.01          60.0
# 16709      0.00      0.01      0.00         0.00          0.01          63.0
#
#        Critic_Count  User_Score  User_Count  Year_of_Release
# 0              51.0         8.0       322.0           2006.0
# 2              73.0         8.3       709.0           2008.0
# 3              73.0         8.0       192.0           2009.0
# 6              65.0         8.5       431.0           2006.0
# 7              41.0         6.6       129.0           2006.0
# ...             ...         ...         ...              ...
# 16677          12.0         8.8         9.0           2002.0
# 16696          20.0         7.6       412.0           2014.0
# 16700          12.0         5.8        43.0           2011.0
# 16706          12.0         7.2        13.0           2011.0
# 16709           6.0         5.8         8.0           2009.0
#
# [6890 rows x 10 columns]

# %%
numdf.describe()
# Out:
#           NA_Sales     EU_Sales     JP_Sales  Other_Sales  Global_Sales  \
# count  6890.000000  6890.000000  6890.000000  6890.000000   6890.000000
# mean      0.391090     0.234633     0.063904     0.082042      0.771851
# std       0.963483     0.684395     0.286540     0.268692      1.955287
# min       0.000000     0.000000     0.000000     0.000000      0.010000
# 25%       0.060000     0.020000     0.000000     0.010000      0.110000
# 50%       0.150000     0.060000     0.000000     0.020000      0.290000
# 75%       0.390000     0.210000     0.010000     0.070000      0.750000
# max      41.360000    28.960000     6.500000    10.570000     82.530000
#
#        Critic_Score  Critic_Count   User_Score    User_Count  Year_of_Release
# count   6890.000000   6890.000000  6890.000000   6890.000000      6890.000000
# mean      70.265022     28.852250     7.184978    174.469376      2007.481858
# std       13.857412     19.194891     1.439574    585.032673         4.236859
# min       13.000000      3.000000     0.500000      4.000000      1985.000000
# 25%       62.000000     14.000000     6.500000     11.000000      2004.000000
# 50%       72.000000     24.000000     7.500000     27.000000      2007.000000
# 75%       80.000000     39.000000     8.200000     89.000000      2011.000000
# max       98.000000    113.000000     9.600000  10665.000000      2016.000000

# %% [markdown]
# ### Sales
#
# Possbile ideas: Plot sales according to total sales of platform/publisher

# %%
# f, axes = plt.subplots(5,1,figsize=(40,60))
f = plt.figure(figsize=(16, 8))
sb.boxplot(data = numdf['NA_Sales'], orient = "h")
plt.show()

# %%
# f, axes = plt.subplots(5,1,figsize=(40,60))
f = plt.figure(figsize=(16, 8))
sb.boxplot(data = numdf['Global_Sales'], orient = "h")
plt.show()

# %%
# f, axes = plt.subplots(5,1,figsize=(40,60))
f = plt.figure(figsize=(16, 8))
sb.histplot(data = numdf['Global_Sales'])
plt.show()

# %%
# f, axes = plt.subplots(5,1,figsize=(40,60))
f = plt.figure(figsize=(16, 8))
sb.violinplot(data = numdf['Global_Sales'], orient = "h")
plt.show()

# %%
cGlobals=numdf['Global_Sales'].value_counts()
print(cGlobals)
# Out:
# 0.02    220
# 0.05    178
# 0.03    177
# 0.04    167
# 0.06    167
#        ...
# 4.46      1
# 4.49      1
# 4.57      1
# 4.59      1
# 2.81      1
# Name: Global_Sales, Length: 536, dtype: int64

# %%
# f, axes = plt.subplots(5,1,figsize=(40,60))
f = plt.figure(figsize=(16, 8))
sb.boxplot(data = numdf['Global_Sales'], orient = "h")
f = plt.figure(figsize=(16, 8))
sb.histplot(data = numdf['Global_Sales'])
f = plt.figure(figsize=(16, 8))
sb.violinplot(data = numdf['Global_Sales'], orient = "h")
plt.show()

# %%
# f, axes = plt.subplots(5,1,figsize=(40,60))
f = plt.figure(figsize=(16, 8))
sb.boxplot(data = numdf['NA_Sales'], orient = "h")
f = plt.figure(figsize=(16, 8))
sb.histplot(data = numdf['NA_Sales'])
f = plt.figure(figsize=(16, 8))
sb.violinplot(data = numdf['NA_Sales'], orient = "h")
plt.show()

# %%
# f, axes = plt.subplots(5,1,figsize=(40,60))
f = plt.figure(figsize=(16, 8))
sb.boxplot(data = numdf['EU_Sales'], orient = "h")
f = plt.figure(figsize=(16, 8))
sb.histplot(data = numdf['EU_Sales'])
f = plt.figure(figsize=(16, 8))
sb.violinplot(data = numdf['EU_Sales'], orient = "h")
plt.show()

# %%
f, axes = plt.subplots(3,figsize=(24, 24))
sb.boxplot(data = numdf["JP_Sales"], orient = "h", ax = axes[0])
sb.histplot(data = numdf["JP_Sales"],ax = axes[1])
sb.violinplot(data = numdf["JP_Sales"], orient = "h", ax = axes[2])
plt.show()

# %%
# f, axes = plt.subplots(5,1,figsize=(40,60))
f = plt.figure(figsize=(16, 8))
sb.boxplot(data = numdf['Other_Sales'], orient = "h")
f = plt.figure(figsize=(16, 8))
sb.histplot(data = numdf['Other_Sales'])
f = plt.figure(figsize=(16, 8))
sb.violinplot(data = numdf['Other_Sales'], orient = "h")
plt.show()

# %% [markdown]
# ### Score
# Time to analyse and find our important variable, probably User Score or Critic Score

# %%
numdf["User_Score"].describe()
# Out:
# count    6890.000000
# mean        7.184978
# std         1.439574
# min         0.500000
# 25%         6.500000
# 50%         7.500000
# 75%         8.200000
# max         9.600000
# Name: User_Score, dtype: float64

# %%
f, axes = plt.subplots(3,figsize=(24, 24))
sb.boxplot(data = numdf["User_Score"], orient = "h", ax = axes[0])
sb.histplot(data = numdf["User_Score"],ax = axes[1])
sb.violinplot(data = numdf["User_Score"], orient = "h", ax = axes[2])
plt.show()

# %%
numdf["User_Count"].describe()
# Out:
# count     6890.000000
# mean       174.469376
# std        585.032673
# min          4.000000
# 25%         11.000000
# 50%         27.000000
# 75%         89.000000
# max      10665.000000
# Name: User_Count, dtype: float64

# %%
f, axes = plt.subplots(3,figsize=(24, 24))
sb.boxplot(data = numdf["User_Count"], orient = "h", ax = axes[0])
sb.histplot(data = numdf["User_Count"],ax = axes[1])
sb.violinplot(data = numdf["User_Count"], orient = "h", ax = axes[2])
plt.show()

# %% [markdown]
# Count kind bad and score better

# %%
numdf["Critic_Score"].describe()
# Out:
# count    6890.000000
# mean       70.265022
# std        13.857412
# min        13.000000
# 25%        62.000000
# 50%        72.000000
# 75%        80.000000
# max        98.000000
# Name: Critic_Score, dtype: float64

# %%
f, axes = plt.subplots(3,figsize=(24, 24))
sb.boxplot(data = numdf["Critic_Score"], orient = "h", ax = axes[0])
sb.histplot(data = numdf["Critic_Score"],ax = axes[1])
sb.violinplot(data = numdf["Critic_Score"], orient = "h", ax = axes[2])
plt.show()

# %% [markdown]
# ### Year of Release
# Time to analyse year of release variable

# %%
numdf["Year_of_Release"].describe()
# Out:
# count    6890.000000
# mean     2007.481858
# std         4.236859
# min      1985.000000
# 25%      2004.000000
# 50%      2007.000000
# 75%      2011.000000
# max      2016.000000
# Name: Year_of_Release, dtype: float64

# %%
f, axes = plt.subplots(3,figsize=(24, 24))
sb.boxplot(data = numdf["Year_of_Release"], orient = "h", ax = axes[0])
sb.histplot(data = numdf["Year_of_Release"],ax = axes[1])
sb.violinplot(data = numdf["Year_of_Release"], orient = "h", ax = axes[2])
plt.show()

# %%
f, axes = plt.subplots(3,figsize=(16, 24))
sb.boxplot(data = numdf["Year_of_Release"], orient = "h", ax = axes[0])
sb.histplot(data = numdf["Year_of_Release"],ax = axes[1])
sb.violinplot(data = numdf["Year_of_Release"], orient = "h", ax = axes[2])
plt.show()

# %% [markdown]
# ## Correlation Matrix

# %%
# Heatmap of the Correlation Matrix
f = plt.figure(figsize=(12,12))
sb.heatmap(numdf.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f")
plt.show()

# %%
sb.pairplot(data = numdf, corner = True)
plt.show()
